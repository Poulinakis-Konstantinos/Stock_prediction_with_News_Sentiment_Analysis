# %%
import pandas as pd
import matplotlib.pyplot as plt 
from pandas_datareader import data as pdr
import yfinance as yf
import numpy as np 
from utilities import *

# %%
news = pd.read_csv('Datasets/sp500_news.csv')
news.describe()
# Out:
#          Unnamed: 0          Open         Close        Volume      Positive  \
# count  20195.000000  20194.000000  20194.000000  2.019400e+04  20195.000000
# mean   10097.000000    117.795628    117.873451  1.787821e+07      0.259090
# std     5829.938679    190.824796    191.168874  2.711953e+07      0.263018
# min        0.000000      0.050000      0.050000  0.000000e+00      0.006623
# 25%     5048.500000     43.900002     43.930000  4.791150e+06      0.050929
# 50%    10097.000000     69.663754     69.825001  9.312500e+06      0.149543
# 75%    15145.500000    120.530001    120.599998  1.793790e+07      0.397669
# max    20194.000000   2645.000000   2647.449951  6.166205e+08      0.959081
#
#            Negative       Neutral  Price_change
# count  20195.000000  20195.000000  20195.000000
# mean       0.191151      0.549759      0.039960
# std        0.254208      0.301388      0.999226
# min        0.006028      0.009800     -1.000000
# 25%        0.021655      0.318067     -1.000000
# 50%        0.058588      0.566472      1.000000
# 75%        0.273883      0.853846      1.000000
# max        0.975977      0.955864      1.000000

# %%
dates = news.date.unique()
news
# Out:
#        Unnamed: 0        date stock        Open       Close       Volume  \
# 0               0  2020-03-09  AAPL   65.937500   66.542503  286744800.0
# 1               1  2020-03-10  AAPL   69.285004   71.334999  285290000.0
# 2               2  2020-03-11  AAPL   69.347504   68.857498  255598800.0
# 3               3  2020-03-12  AAPL   63.985001   62.057499  418474000.0
# 4               4  2020-03-13  AAPL   66.222504   69.492500  370732000.0
# ...           ...         ...   ...         ...         ...          ...
# 20190       20190  2020-06-04   AXP  103.470001  106.540001    5841600.0
# 20191       20191  2020-06-05   AXP  114.110001  109.730003   10097600.0
# 20192       20192  2020-06-08   AXP  111.910004  113.669998    6795200.0
# 20193       20193  2020-06-09   AXP  110.080002  110.459999    5517400.0
# 20194       20194  2020-06-10   AXP  110.000000  106.160004    5747400.0
#
#        Positive  Negative   Neutral  Price_change
# 0      0.046127  0.411464  0.542409            -1
# 1      0.070845  0.449025  0.480130             1
# 2      0.190995  0.453761  0.355244            -1
# 3      0.204221  0.447518  0.348261            -1
# 4      0.315863  0.218127  0.466010             1
# ...         ...       ...       ...           ...
# 20190  0.876779  0.016645  0.106576             1
# 20191  0.929944  0.026850  0.043206             1
# 20192  0.897881  0.032619  0.069500             1
# 20193  0.012436  0.890337  0.097227            -1
# 20194  0.387856  0.503540  0.108604            -1
#
# [20195 rows x 10 columns]

# %%
big_df = news 
incr = len(big_df[big_df['Price_change']==1])
decr = big_df.shape[0] - incr
incr_ratio = (100 * incr) / big_df.shape[0]
decr_ratio = (100 * decr) / big_df.shape[0]
incr_to_decr = (incr/decr)

print('Dataset contains :\n \
{} ({:.2f}%) number of price increace examples \n \
{}  ({:.2f}%) number of price decrease examples. \n \
{:.2f}  increase to decrease examples ratio'\
.format(incr, decr, incr_ratio, decr_ratio, incr_to_decr))

fig, ax = plt.subplots(figsize=(6,6))
plt.pie(x=[incr, decr], labels=['Increasing_price','Decreasing_price'], shadow=True, autopct='%1.1f%%')
plt.title('Increasing vs Decreasing Observations', fontsize=18)
plt.show()
# Out:
# Dataset contains :
#  10501 (9694.00%) number of price increace examples
#  51.99801931171082  (48.00%) number of price decrease examples.
#  1.08  increase to decrease examples ratio

# %%
print(len(dates))
np.sort(dates)
# Out:
# 2609
# array(['2010-01-05', '2010-01-06', '2010-01-07', ..., '2020-06-09',
#        '2020-06-10', '2020-06-11'], dtype=object)

# %% [markdown]
# #### Group news dataframe by date , ignore company name.

# %%
sent_df = news.groupby(by = 'date').mean()
sent_df = sent_df.drop(['Unnamed: 0', 'Open', 'Close', 'Price_change'], axis=1)
sent_df
# Out:
#                   Volume  Positive  Negative   Neutral
# date
# 2010-01-05  1.111477e+07  0.157785  0.489590  0.352625
# 2010-01-06  9.592200e+06  0.159253  0.114102  0.726645
# 2010-01-07  1.264640e+07  0.441000  0.012006  0.546994
# 2010-01-08  1.508503e+07  0.039152  0.384472  0.576376
# 2010-01-11  7.396000e+06  0.114053  0.029774  0.856173
# ...                  ...       ...       ...       ...
# 2020-06-05  2.503270e+07  0.567891  0.070503  0.361606
# 2020-06-08  2.303770e+07  0.523481  0.124646  0.351873
# 2020-06-09  2.969893e+07  0.296441  0.337487  0.366072
# 2020-06-10  3.795272e+07  0.390972  0.240399  0.368628
# 2020-06-11  1.970420e+07  0.067369  0.743126  0.189504
#
# [2609 rows x 4 columns]

# %%
sp500 =  financial_dataset("^GSPC",2, start_date="2010-01-01",end_date= "2020-6-12")
sp500
# Out:
# [*********************100%***********************]  1 of 1 completed
# ^GSPC financial dataframe dimensions  (2629, 6)
# Positive changes : 1441
# Negative changes : 1188
# No changes : 0
#                    Open        Close      Volume  Price_change        date
# Date
# 2009-12-31  1126.599976  1115.099976  2076990000             1           0
# 2010-01-04  1116.560059  1132.989990  3991400000             1  2010-01-04
# 2010-01-05  1132.660034  1136.520020  2491020000             1  2010-01-05
# 2010-01-06  1135.709961  1137.140015  4972660000             1  2010-01-06
# 2010-01-07  1136.270020  1141.689941  5270680000             1  2010-01-07
# ...                 ...          ...         ...           ...         ...
# 2020-06-05  3163.840088  3193.929932  8617590000             1  2020-06-05
# 2020-06-08  3199.919922  3232.389893  8437380000             1  2020-06-08
# 2020-06-09  3213.320068  3207.179932  6382620000            -1  2020-06-09
# 2020-06-10  3213.419922  3190.139893  6570840000            -1  2020-06-10
# 2020-06-11  3123.530029  3002.100098  7018890000            -1  2020-06-11
#
# [2629 rows x 5 columns]

# %%
data = sp500.merge(sent_df, on='date', how='inner')
data = data.drop(['Open', 'Volume_x'], axis=1)
data = data.rename({'Volume_y':'Volume'}, axis=1)
data = data[['date','Volume', 'Close', 'Positive', 'Negative', 'Neutral', 'Price_change']]
data
# Out:
#             date        Volume        Close  Positive  Negative   Neutral  \
# 0     2010-01-05  1.111477e+07  1136.520020  0.157785  0.489590  0.352625
# 1     2010-01-06  9.592200e+06  1137.140015  0.159253  0.114102  0.726645
# 2     2010-01-07  1.264640e+07  1141.689941  0.441000  0.012006  0.546994
# 3     2010-01-08  1.508503e+07  1144.979980  0.039152  0.384472  0.576376
# 4     2010-01-11  7.396000e+06  1146.979980  0.114053  0.029774  0.856173
# ...          ...           ...          ...       ...       ...       ...
# 2603  2020-06-05  2.503270e+07  3193.929932  0.567891  0.070503  0.361606
# 2604  2020-06-08  2.303770e+07  3232.389893  0.523481  0.124646  0.351873
# 2605  2020-06-09  2.969893e+07  3207.179932  0.296441  0.337487  0.366072
# 2606  2020-06-10  3.795272e+07  3190.139893  0.390972  0.240399  0.368628
# 2607  2020-06-11  1.970420e+07  3002.100098  0.067369  0.743126  0.189504
#
#       Price_change
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 2603             1
# 2604             1
# 2605            -1
# 2606            -1
# 2607            -1
#
# [2608 rows x 7 columns]

# %%
data.to_csv('Datasets/sp500_sentiment_non_weighted.csv')
